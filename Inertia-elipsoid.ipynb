# %%
import Inertia as i
import numpy as np

# %%
# Some test points --- First array contains the coordinates, second one the mass
P1 = [np.array([2, 1/3, 0], dtype=np.float64), [1]]
P2 = [np.array([13, 1/5, 0], dtype=np.float64), [1]]
P3 = [np.array([1/4, -1, 3], dtype=np.float64), [1]]
P4 = [np.array([-5, 1, 4/5], dtype=np.float64), [1]]
P5 = [np.array([4, 3, -2], dtype=np.float64), [1]]
lstPoints1 = [P1, P2, P3, P4, P5]

# %%
p1 = [np.array([-1, 1, 0], dtype=np.float64), [1]]
p2 = [np.array([1, -1, 0], dtype=np.float64), [1]]
p3 = [np.array([0, -1, 2], dtype=np.float64), [1]]
lstPoints2 = [p1, p2, p3]

# %%
i.getInertiaTensor(lstPoints2)
# Out:
# array([[7., 2., 0.],
#        [2., 6., 2.],
#        [0., 2., 5.]])

# %%
i.pltElipsoid(i.getInertiaTensor(lstPoints2))
