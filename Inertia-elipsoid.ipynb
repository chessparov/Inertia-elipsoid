# %%
import Inertia as i
import numpy as np

# %%
# Some test points
p1 = [np.array([-1, 1, 0], dtype=np.float64), [1]]
p2 = [np.array([1, -1, 0], dtype=np.float64), [1]]
p3 = [np.array([0, -1, 2], dtype=np.float64), [1]]
lstPoints = [p1, p2, p3]

# %%
i.getInertiaTensor(False, lstPoints)
# Out:
# array([[7., 2., 0.],
#        [2., 6., 2.],
#        [0., 2., 5.]])

# %%
i.pltElipsoid(i.getInertiaTensor(False, lstPoints))

# %%
rettangolo = i.Continuum(0, [1, 0, 0], [0, 1], 1, 1)

# %%
i.getInertiaTensor(True, rettangolo)
# Out:
# array([[ 0.33333333, -0.25      ,  0.        ],
#        [-0.25      ,  0.33333333,  0.        ],
#        [ 0.        ,  0.        ,  0.66666667]])

# %%
i.pltElipsoid(i.getInertiaTensor(True, rettangolo))
